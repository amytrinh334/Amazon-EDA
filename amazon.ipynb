# %% [markdown]
# Step 1: Loading Dataset

# %%
#Importing required modules
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
#Loading the dataset
amazon = pd.read_csv("amazon.csv")

# %%
amazon.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %%
amazon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %%
amazon.shape
# Out:
# (1465, 16)

# %%
amazon.describe()
# Out:
#         product_id                                       product_name  \
# count         1465                                               1465
# unique        1351                                               1337
# top     B07JW9H4J1  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# freq             3                                                  5
#
#                                                  category discounted_price  \
# count                                                1465             1465
# unique                                                211              550
# top     Computers&Accessories|Accessories&Peripherals|...             ₹199
# freq                                                  233               53
#
#        actual_price discount_percentage rating rating_count  \
# count          1465                1465   1465         1463
# unique          449                  92     28         1143
# ...

# %% [markdown]
# Step 2: Data Cleaning

# %%
amazon.isnull().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
amazon.dropna()
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# ...

# %%
#Converting certain columns to numerical data types for later use
amazon['discounted_price'] = amazon['discounted_price'].str.replace('₹', '', regex=False).str.replace(',', '', regex=False)
amazon['actual_price'] = amazon['actual_price'].str.replace('₹', '', regex=False).str.replace(',', '', regex=False)
amazon['discount_percentage'] = amazon['discount_percentage'].str.replace('%', '', regex=False)
amazon['rating_count'] = amazon['rating_count'].str.replace(',', '', regex=False)

columns = ["discounted_price","actual_price","discount_percentage","rating_count"]
for col in columns:
    amazon[col]=amazon[col].astype(float)

# %%
amazon.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             399.0
# 1  Computers&Accessories|Accessories&Peripherals|...             199.0
# 2  Computers&Accessories|Accessories&Peripherals|...             199.0
# 3  Computers&Accessories|Accessories&Peripherals|...             329.0
# 4  Computers&Accessories|Accessories&Peripherals|...             154.0
#
#    actual_price  discount_percentage rating  rating_count  \
# 0        1099.0                 64.0    4.2       24269.0
# ...

# %%
#converting Rupees into USD
rupees = ["discounted_price","actual_price"]
for col in rupees:
    amazon[col] = amazon[col] * 0.011
    amazon[col]= amazon[col].round(2)

# %%
amazon.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...              4.39
# 1  Computers&Accessories|Accessories&Peripherals|...              2.19
# 2  Computers&Accessories|Accessories&Peripherals|...              2.19
# 3  Computers&Accessories|Accessories&Peripherals|...              3.62
# 4  Computers&Accessories|Accessories&Peripherals|...              1.69
#
#    actual_price  discount_percentage rating  rating_count  \
# 0         12.09                 64.0    4.2       24269.0
# ...

# %%
#Simplifying category names
split_category = amazon['category'].str.split('|')
amazon['category'] = split_category.str[0]
amazon['item_type'] = split_category.str[-1]

amazon['category'] = amazon['category'].str.replace('&', ' & ', regex=False)
amazon['item_type'] = amazon['item_type'].str.replace('&', ' & ', regex=False)

amazon.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                   category  discounted_price  actual_price  \
# 0  Computers & Accessories              4.39         12.09
# 1  Computers & Accessories              2.19          3.84
# 2  Computers & Accessories              2.19         20.89
# 3  Computers & Accessories              3.62          7.69
# 4  Computers & Accessories              1.69          4.39
#
#    discount_percentage rating  rating_count  \
# 0                 64.0    4.2       24269.0
# 1                 43.0    4.0       43994.0
# 2                 90.0    3.9        7928.0
# ...

# %% [markdown]
# Step 3: Data Analysis

# %%
#Barplot for ratings
amazon['rating'] = pd.to_numeric(amazon['rating'], errors='coerce')

plt.figure(figsize=(10,6))
sns.countplot(data=amazon, x="rating", palette="Wistia")
plt.title("Frequency of Product Ratings")
plt.xlabel("Rating")
plt.ylabel("Counts")
plt.show()

# %%
#numerical variable heatmap
plt.figure(figsize=(10,6))
correlation = amazon[["discounted_price","actual_price","discount_percentage","rating","rating_count"]]
sns.heatmap(correlation.corr(), annot=True, cmap="vlag")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(data=amazon, x='category', y='rating', inner='box')
plt.xticks(rotation=45)
plt.title('Rating Density per Category')
# Out:
# Text(0.5, 1.0, 'Rating Density per Category')

# %%
plt.figure(figsize=(10, 6))
sns.countplot(
    data=amazon, 
    y='category', 
    order=amazon['category'].value_counts().index,
    palette='viridis'
)

plt.title('Most Popular Project Categories', fontsize=15)
plt.xlabel('Number of Products')
plt.ylabel('Category')
plt.show()

# %%
plt.figure(figsize=(10, 6))

top_10 = amazon['item_type'].value_counts().head(10).index


sns.countplot(
    data=amazon[amazon['item_type'].isin(top_10)], 
    y='item_type', 
    order=top_10,
    palette='viridis'
)

plt.title('Top 10 Most Popular Product Types', fontsize=15)
plt.xlabel('Number of Products')
plt.ylabel('Item Type')
plt.show()

# %%
plt.figure(figsize=(10, 6))

sns.scatterplot(
    data=amazon, 
    x='discounted_price', 
    y='rating', 
    alpha=0.4,
    color='darkblue'
)
plt.title('Discount Price vs. Product Rating', fontsize=15)
plt.xlabel('Discount Price (USD)', fontsize=12)
plt.ylabel('Rating', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %%
plt.figure(figsize=(10, 6))

sns.scatterplot(
    data=amazon, 
    x='discount_percentage', 
    y='rating', 
    alpha=0.4,
    color='darkblue'
)
plt.title('Discount Percentage vs. Product Rating', fontsize=15)
plt.xlabel('Discount Percentage (%)', fontsize=12)
plt.ylabel('Rating', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=amazon, x='rating_count', y='rating', alpha=0.5)
plt.xscale('log') # Use log scale because some products have 10 reviews and others 100,000
plt.title('Rating vs. Number of Reviews (Log Scale)')
plt.show()

# %%
C = amazon['rating'].mean()
m = amazon['rating_count'].quantile(0.75) # Using the top 25% as the threshold

def weighted_rating(x, m=m, C=C):
    v = x['rating_count']
    R = x['rating']
    return (v/(v+m) * R) + (m/(v+m) * C)

amazon['weighted_score'] = amazon.apply(weighted_rating, axis=1)

# %%
plt.figure(figsize=(10, 5))

sns.kdeplot(amazon['rating'], label='Raw Rating', fill=True, alpha=0.3, color='gray')
sns.kdeplot(amazon['weighted_score'], label='Weighted Score', fill=True, alpha=0.5, color='teal')

plt.title('Distribution: Raw Rating vs. Weighted Score')
plt.xlabel('Score')
plt.ylabel('Density')
plt.legend()
plt.show()
